# %% [markdown]
# <a href="https://colab.research.google.com/github/deucxqug/AED_Practica1.1/blob/feature-saludo/feature_saludo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
function saludar(nombre)
  return "Hola, $nombre, Bienvenido a la Ciencia de Datos."
end

println(saludar("Estudiante"))
# Out:
# Hola, Estudiante, Bienvenido a la Ciencia de Datos.
